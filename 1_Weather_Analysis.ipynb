# %% [markdown]
# <a href="https://colab.research.google.com/github/sabaakram539/data_analysis_projects/blob/main/1_Weather_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # The Weather Data
# Here the weather dataset is a time series dataset with per hour information about the weather conditions at a particular location. It records temperature, Dew Point Temperature, Relative Humidity, windspeed, visibility pressure and conditions.
#
# The data is available as a csv file. We are going to analyse this data using the pandas dataframe.

# %%
import pandas as pd

# %%
data=pd.read_csv('1. Weather Data.csv')
data.head()
# Out:
#        Date/Time  Temp_C  ...  Press_kPa               Weather
# 0  1/1/2012 0:00    -1.8  ...     101.24                   Fog
# 1  1/1/2012 1:00    -1.8  ...     101.24                   Fog
# 2  1/1/2012 2:00    -1.8  ...     101.26  Freezing Drizzle,Fog
# 3  1/1/2012 3:00    -1.5  ...     101.27  Freezing Drizzle,Fog
# 4  1/1/2012 4:00    -1.5  ...     101.23                   Fog
#
# [5 rows x 8 columns]

# %%
data.shape
# Out:
# (8784, 8)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=8784, step=1)

# %%
data.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Date/Time            object
# Temp_C              float64
# Dew Point Temp_C    float64
# Rel Hum_%             int64
# Wind Speed_km/h       int64
# Visibility_km       float64
# Press_kPa           float64
# Weather              object
# dtype: object

# %%
data.rename(columns={'Date/Time':'Date_Time','Temp_C':'Temperature','Dew Point Temp_C':'Dew_Pt_Temp',
                     'Rel Hum_%':'Relative_Humidity','Wind Speed_km/h':'Wind_Speed','Visibility_km':'Visibility'
                     ,'Press_kPa':'Pressure'},inplace=True)

# %%
data.columns
# Out:
# Index(['Date_Time', 'Temperature', 'Dew_Pt_Temp', 'Relative_Humidity',
#        'Wind_Speed', 'Visibility', 'Pressure', 'Weather'],
#       dtype='object')

# %%
 data.Weather.unique()
# Out:
# array(['Fog', 'Freezing Drizzle,Fog', 'Mostly Cloudy', 'Cloudy', 'Rain',
#        'Rain Showers', 'Mainly Clear', 'Snow Showers', 'Snow', 'Clear',
#        'Freezing Rain,Fog', 'Freezing Rain', 'Freezing Drizzle',
#        'Rain,Snow', 'Moderate Snow', 'Freezing Drizzle,Snow',
#        'Freezing Rain,Snow Grains', 'Snow,Blowing Snow', 'Freezing Fog',
#        'Haze', 'Rain,Fog', 'Drizzle,Fog', 'Drizzle',
#        'Freezing Drizzle,Haze', 'Freezing Rain,Haze', 'Snow,Haze',
#        'Snow,Fog', 'Snow,Ice Pellets', 'Rain,Haze', 'Thunderstorms,Rain',
#        'Thunderstorms,Rain Showers', 'Thunderstorms,Heavy Rain Showers',
#        'Thunderstorms,Rain Showers,Fog', 'Thunderstorms',
#        'Thunderstorms,Rain,Fog',
#        'Thunderstorms,Moderate Rain Showers,Fog', 'Rain Showers,Fog',
#        'Rain Showers,Snow Showers', 'Snow Pellets', 'Rain,Snow,Fog',
#        'Moderate Rain,Fog', 'Freezing Rain,Ice Pellets,Fog',
# ...

# %%
 data.Weather.nunique()
# Out:
# 50

# %%
data.Weather.value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Haze                                         16
# Thunderstorms,Rain Showers                   16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %%
data.count()
# Out:
# Date_Time            8784
# Temperature          8784
# Dew_Pt_Temp          8784
# Relative_Humidity    8784
# Wind_Speed           8784
# Visibility           8784
# Pressure             8784
# Weather              8784
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Date_Time          8784 non-null   object
#  1   Temperature        8784 non-null   float64
#  2   Dew_Pt_Temp        8784 non-null   float64
#  3   Relative_Humidity  8784 non-null   int64
#  4   Wind_Speed         8784 non-null   int64
#  5   Visibility         8784 non-null   float64
#  6   Pressure           8784 non-null   float64
#  7   Weather            8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %%
data.describe()
# Out:
#        Temperature  Dew_Pt_Temp  ...   Visibility     Pressure
# count  8784.000000  8784.000000  ...  8784.000000  8784.000000
# mean      8.798144     2.555294  ...    27.664447   101.051623
# std      11.687883    10.883072  ...    12.622688     0.844005
# min     -23.300000   -28.500000  ...     0.200000    97.520000
# 25%       0.100000    -5.900000  ...    24.100000   100.560000
# 50%       9.300000     3.300000  ...    25.000000   101.070000
# 75%      18.800000    11.800000  ...    25.000000   101.590000
# max      33.000000    24.400000  ...    48.300000   103.650000
#
# [8 rows x 6 columns]

# %%
data.Weather.unique()
# Out:
# array(['Fog', 'Freezing Drizzle,Fog', 'Mostly Cloudy', 'Cloudy', 'Rain',
#        'Rain Showers', 'Mainly Clear', 'Snow Showers', 'Snow', 'Clear',
#        'Freezing Rain,Fog', 'Freezing Rain', 'Freezing Drizzle',
#        'Rain,Snow', 'Moderate Snow', 'Freezing Drizzle,Snow',
#        'Freezing Rain,Snow Grains', 'Snow,Blowing Snow', 'Freezing Fog',
#        'Haze', 'Rain,Fog', 'Drizzle,Fog', 'Drizzle',
#        'Freezing Drizzle,Haze', 'Freezing Rain,Haze', 'Snow,Haze',
#        'Snow,Fog', 'Snow,Ice Pellets', 'Rain,Haze', 'Thunderstorms,Rain',
#        'Thunderstorms,Rain Showers', 'Thunderstorms,Heavy Rain Showers',
#        'Thunderstorms,Rain Showers,Fog', 'Thunderstorms',
#        'Thunderstorms,Rain,Fog',
#        'Thunderstorms,Moderate Rain Showers,Fog', 'Rain Showers,Fog',
#        'Rain Showers,Snow Showers', 'Snow Pellets', 'Rain,Snow,Fog',
#        'Moderate Rain,Fog', 'Freezing Rain,Ice Pellets,Fog',
# ...

# %%
data.Weather.nunique()
# Out:
# 50

# %%
data.Weather.value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Haze                                         16
# Thunderstorms,Rain Showers                   16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %% [markdown]
# Finding all unique windspeed values

# %%
data.head(2)
# Out:
#        Date_Time  Temperature  Dew_Pt_Temp  ...  Visibility  Pressure  Weather
# 0  1/1/2012 0:00         -1.8         -3.9  ...         8.0    101.24      Fog
# 1  1/1/2012 1:00         -1.8         -3.7  ...         8.0    101.24      Fog
#
# [2 rows x 8 columns]

# %%
data.Wind_Speed.unique()
# Out:
# array([ 4,  7,  6,  9, 15, 13, 20, 22, 19, 24, 30, 35, 39, 32, 33, 26, 44,
#        43, 48, 37, 28, 17, 11,  0, 83, 70, 57, 46, 41, 52, 50, 63, 54,  2])

# %%
data.Wind_Speed.nunique()
# Out:
# 34

# %% [markdown]
# Finding number of times weather is exactly clear.

# %%
# Value_Counts
data.Weather.value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Haze                                         16
# Thunderstorms,Rain Showers                   16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %%
#Filtering
data[data.Weather=='Clear']
# Out:
#              Date_Time  Temperature  Dew_Pt_Temp  ...  Visibility  Pressure  Weather
# 67      1/3/2012 19:00        -16.9        -24.8  ...        25.0    101.74    Clear
# 114     1/5/2012 18:00         -7.1        -14.4  ...        25.0    100.71    Clear
# 115     1/5/2012 19:00         -9.2        -15.4  ...        25.0    100.80    Clear
# 116     1/5/2012 20:00         -9.8        -15.7  ...        25.0    100.83    Clear
# 117     1/5/2012 21:00         -9.0        -14.8  ...        25.0    100.83    Clear
# ...                ...          ...          ...  ...         ...       ...      ...
# 8646   12/26/2012 6:00        -13.4        -14.8  ...        25.0    102.47    Clear
# 8698  12/28/2012 10:00         -6.1         -8.6  ...        24.1    101.27    Clear
# 8713   12/29/2012 1:00        -11.9        -13.6  ...        25.0    101.31    Clear
# 8714   12/29/2012 2:00        -11.8        -13.1  ...        25.0    101.33    Clear
# ...

# %%
#Groupby Method
data.groupby('Weather').get_group('Clear')
# Out:
#              Date_Time  Temperature  Dew_Pt_Temp  ...  Visibility  Pressure  Weather
# 67      1/3/2012 19:00        -16.9        -24.8  ...        25.0    101.74    Clear
# 114     1/5/2012 18:00         -7.1        -14.4  ...        25.0    100.71    Clear
# 115     1/5/2012 19:00         -9.2        -15.4  ...        25.0    100.80    Clear
# 116     1/5/2012 20:00         -9.8        -15.7  ...        25.0    100.83    Clear
# 117     1/5/2012 21:00         -9.0        -14.8  ...        25.0    100.83    Clear
# ...                ...          ...          ...  ...         ...       ...      ...
# 8646   12/26/2012 6:00        -13.4        -14.8  ...        25.0    102.47    Clear
# 8698  12/28/2012 10:00         -6.1         -8.6  ...        24.1    101.27    Clear
# 8713   12/29/2012 1:00        -11.9        -13.6  ...        25.0    101.31    Clear
# 8714   12/29/2012 2:00        -11.8        -13.1  ...        25.0    101.33    Clear
# ...

# %% [markdown]
# Finding number of times when the windspeed is exactly 4 km/h

# %%
data.head(2)
# Out:
#        Date_Time  Temperature  Dew_Pt_Temp  ...  Visibility  Pressure  Weather
# 0  1/1/2012 0:00         -1.8         -3.9  ...         8.0    101.24      Fog
# 1  1/1/2012 1:00         -1.8         -3.7  ...         8.0    101.24      Fog
#
# [2 rows x 8 columns]

# %%
#Filtering
data[data.Wind_Speed==4]
# Out:
#              Date_Time  Temperature  ...  Pressure       Weather
# 0        1/1/2012 0:00         -1.8  ...    101.24           Fog
# 1        1/1/2012 1:00         -1.8  ...    101.24           Fog
# 96       1/5/2012 0:00         -8.8  ...    100.32          Snow
# 101      1/5/2012 5:00         -7.0  ...    100.19          Snow
# 146      1/7/2012 2:00         -8.1  ...    100.15        Cloudy
# ...                ...          ...  ...       ...           ...
# 8768   12/31/2012 8:00         -8.6  ...    101.14  Snow Showers
# 8769   12/31/2012 9:00         -8.1  ...    101.09          Snow
# 8770  12/31/2012 10:00         -7.4  ...    101.05      Snow,Fog
# 8772  12/31/2012 12:00         -5.8  ...    100.78          Snow
# 8773  12/31/2012 13:00         -4.6  ...    100.63          Snow
#
# [474 rows x 8 columns]

# %%
# Value Counts method
data.Wind_Speed.value_counts()
# Out:
# 9     830
# 11    791
# 13    735
# 15    719
# 7     677
# 17    666
# 19    616
# 6     609
# 20    496
# 4     474
# 22    439
# 24    374
# 0     309
# 26    242
# 28    205
# 30    161
# 32    139
# 33     85
# 35     53
# 37     45
# 39     24
# 41     22
# 44     14
# 43     13
# 48     13
# 46     11
# 52      7
# 57      5
# 50      4
# 2       2
# 63      1
# 54      1
# 70      1
# 83      1
# Name: Wind_Speed, dtype: int64

# %%
# Groupby Method
data.groupby('Wind_Speed').get_group(4)
# Out:
#              Date_Time  Temperature  ...  Pressure       Weather
# 0        1/1/2012 0:00         -1.8  ...    101.24           Fog
# 1        1/1/2012 1:00         -1.8  ...    101.24           Fog
# 96       1/5/2012 0:00         -8.8  ...    100.32          Snow
# 101      1/5/2012 5:00         -7.0  ...    100.19          Snow
# 146      1/7/2012 2:00         -8.1  ...    100.15        Cloudy
# ...                ...          ...  ...       ...           ...
# 8768   12/31/2012 8:00         -8.6  ...    101.14  Snow Showers
# 8769   12/31/2012 9:00         -8.1  ...    101.09          Snow
# 8770  12/31/2012 10:00         -7.4  ...    101.05      Snow,Fog
# 8772  12/31/2012 12:00         -5.8  ...    100.78          Snow
# 8773  12/31/2012 13:00         -4.6  ...    100.63          Snow
#
# [474 rows x 8 columns]

# %% [markdown]
# Finding null values

# %%
data.isnull().sum()
# Out:
# Date_Time            0
# Temperature          0
# Dew_Pt_Temp          0
# Relative_Humidity    0
# Wind_Speed           0
# Visibility           0
# Pressure             0
# Weather              0
# dtype: int64

# %%
data.notnull().sum()
# Out:
# Date_Time            8784
# Temperature          8784
# Dew_Pt_Temp          8784
# Relative_Humidity    8784
# Wind_Speed           8784
# Visibility           8784
# Pressure             8784
# Weather              8784
# dtype: int64

# %% [markdown]
# Finding instances when the snow is recorded.

# %%
# Value Counts
data.Weather.value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Haze                                         16
# Thunderstorms,Rain Showers                   16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %%
#filtering
data[data.Weather=='Snow']
# Out:
#              Date_Time  Temperature  Dew_Pt_Temp  ...  Visibility  Pressure  Weather
# 55       1/3/2012 7:00        -14.0        -19.5  ...        25.0    100.95     Snow
# 84      1/4/2012 12:00        -13.7        -21.7  ...        24.1    101.25     Snow
# 86      1/4/2012 14:00        -11.3        -19.0  ...        19.3    100.97     Snow
# 87      1/4/2012 15:00        -10.2        -16.3  ...         9.7    100.89     Snow
# 88      1/4/2012 16:00         -9.4        -15.5  ...        19.3    100.79     Snow
# ...                ...          ...          ...  ...         ...       ...      ...
# 8779  12/31/2012 19:00          0.1         -2.7  ...         9.7    100.13     Snow
# 8780  12/31/2012 20:00          0.2         -2.4  ...         9.7    100.03     Snow
# 8781  12/31/2012 21:00         -0.5         -1.5  ...         4.8     99.95     Snow
# 8782  12/31/2012 22:00         -0.2         -1.8  ...         9.7     99.91     Snow
# ...

# %%
#Groupby method
data.groupby('Weather').get_group('Snow')
# Out:
#              Date_Time  Temperature  Dew_Pt_Temp  ...  Visibility  Pressure  Weather
# 55       1/3/2012 7:00        -14.0        -19.5  ...        25.0    100.95     Snow
# 84      1/4/2012 12:00        -13.7        -21.7  ...        24.1    101.25     Snow
# 86      1/4/2012 14:00        -11.3        -19.0  ...        19.3    100.97     Snow
# 87      1/4/2012 15:00        -10.2        -16.3  ...         9.7    100.89     Snow
# 88      1/4/2012 16:00         -9.4        -15.5  ...        19.3    100.79     Snow
# ...                ...          ...          ...  ...         ...       ...      ...
# 8779  12/31/2012 19:00          0.1         -2.7  ...         9.7    100.13     Snow
# 8780  12/31/2012 20:00          0.2         -2.4  ...         9.7    100.03     Snow
# 8781  12/31/2012 21:00         -0.5         -1.5  ...         4.8     99.95     Snow
# 8782  12/31/2012 22:00         -0.2         -1.8  ...         9.7     99.91     Snow
# ...

# %%
#Str.contains method
data[data.Weather.str.contains('Snow')]
# Out:
#              Date_Time  Temperature  ...  Pressure       Weather
# 41      1/2/2012 17:00         -2.1  ...     99.66  Snow Showers
# 44      1/2/2012 20:00         -5.6  ...    100.07  Snow Showers
# 45      1/2/2012 21:00         -5.8  ...    100.15  Snow Showers
# 47      1/2/2012 23:00         -7.4  ...    100.27  Snow Showers
# 48       1/3/2012 0:00         -9.0  ...    100.35  Snow Showers
# ...                ...          ...  ...       ...           ...
# 8779  12/31/2012 19:00          0.1  ...    100.13          Snow
# 8780  12/31/2012 20:00          0.2  ...    100.03          Snow
# 8781  12/31/2012 21:00         -0.5  ...     99.95          Snow
# 8782  12/31/2012 22:00         -0.2  ...     99.91          Snow
# 8783  12/31/2012 23:00          0.0  ...     99.89          Snow
#
# [583 rows x 8 columns]

# %% [markdown]
# Finding instances when windspeed is above 24 and visibility 25

# %%
data.head(2)
# Out:
#        Date_Time  Temperature  Dew_Pt_Temp  ...  Visibility  Pressure  Weather
# 0  1/1/2012 0:00         -1.8         -3.9  ...         8.0    101.24      Fog
# 1  1/1/2012 1:00         -1.8         -3.7  ...         8.0    101.24      Fog
#
# [2 rows x 8 columns]

# %%
data[(data['Wind_Speed']>24) & (data['Visibility']==25)]
# Out:
#              Date_Time  Temperature  ...  Pressure        Weather
# 23      1/1/2012 23:00          5.3  ...     99.31         Cloudy
# 24       1/2/2012 0:00          5.2  ...     99.26   Rain Showers
# 25       1/2/2012 1:00          4.6  ...     99.26         Cloudy
# 26       1/2/2012 2:00          3.9  ...     99.26  Mostly Cloudy
# 27       1/2/2012 3:00          3.7  ...     99.30  Mostly Cloudy
# ...                ...          ...  ...       ...            ...
# 8705  12/28/2012 17:00         -8.6  ...    101.34   Mainly Clear
# 8753  12/30/2012 17:00        -12.1  ...    101.26   Mainly Clear
# 8755  12/30/2012 19:00        -13.4  ...    101.47   Mainly Clear
# 8759  12/30/2012 23:00        -12.1  ...    101.52  Mostly Cloudy
# 8760   12/31/2012 0:00        -11.1  ...    101.51         Cloudy
#
# [308 rows x 8 columns]

# %% [markdown]
# Finding the mean value of all weather condition against each columns.

# %%
data.groupby('Weather').mean()
# Out:
#                                          Temperature  ...    Pressure
# Weather                                               ...
# Clear                                       6.825716  ...  101.587443
# Cloudy                                      7.970544  ...  100.911441
# Drizzle                                     7.353659  ...  100.435366
# Drizzle,Fog                                 8.067500  ...  100.786625
# Drizzle,Ice Pellets,Fog                     0.400000  ...  100.790000
# Drizzle,Snow                                1.050000  ...  100.890000
# Drizzle,Snow,Fog                            0.693333  ...   99.281333
# Fog                                         4.303333  ...  101.184067
# Freezing Drizzle                           -5.657143  ...  100.202857
# Freezing Drizzle,Fog                       -2.533333  ...  100.441667
# Freezing Drizzle,Haze                      -5.433333  ...  100.316667
# Freezing Drizzle,Snow                      -5.109091  ...  100.520909
# ...

# %% [markdown]
# Finding the minimum value of each column against the weather condition.

# %%
data.groupby('Weather').min()
# Out:
#                                                 Date_Time  ...  Pressure
# Weather                                                    ...
# Clear                                      1/11/2012 1:00  ...     99.52
# Cloudy                                     1/1/2012 17:00  ...     98.39
# Drizzle                                   1/23/2012 21:00  ...     97.84
# Drizzle,Fog                               1/23/2012 20:00  ...     98.65
# Drizzle,Ice Pellets,Fog                   12/17/2012 9:00  ...    100.79
# Drizzle,Snow                             12/17/2012 15:00  ...    100.63
# Drizzle,Snow,Fog                         12/18/2012 21:00  ...     97.79
# Fog                                         1/1/2012 0:00  ...     98.31
# Freezing Drizzle                          1/13/2012 10:00  ...     98.44
# Freezing Drizzle,Fog                        1/1/2012 2:00  ...     98.74
# Freezing Drizzle,Haze                      2/1/2012 11:00  ...    100.28
# ...

# %% [markdown]
# Finding the miaximum value of each column against the weather condition.

# %%
data.groupby('Weather').max()
# Out:
#                                                 Date_Time  ...  Pressure
# Weather                                                    ...
# Clear                                       9/9/2012 5:00  ...    103.63
# Cloudy                                     9/9/2012 23:00  ...    103.65
# Drizzle                                    9/30/2012 3:00  ...    101.56
# Drizzle,Fog                                9/30/2012 2:00  ...    102.07
# Drizzle,Ice Pellets,Fog                   12/17/2012 9:00  ...    100.79
# Drizzle,Snow                             12/19/2012 18:00  ...    101.15
# Drizzle,Snow,Fog                          12/22/2012 3:00  ...    100.15
# Fog                                        9/22/2012 0:00  ...    103.04
# Freezing Drizzle                            2/1/2012 5:00  ...    101.02
# Freezing Drizzle,Fog                      12/10/2012 5:00  ...    101.27
# Freezing Drizzle,Haze                      2/1/2012 13:00  ...    100.36
# ...

# %% [markdown]
# Finding all the instances where weather is Fog

# %%
# VAlue Counts
data.Weather.value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Haze                                         16
# Thunderstorms,Rain Showers                   16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %%
# Filtering
data[data.Weather=='Fog']
# Out:
#              Date_Time  Temperature  Dew_Pt_Temp  ...  Visibility  Pressure  Weather
# 0        1/1/2012 0:00         -1.8         -3.9  ...         8.0    101.24      Fog
# 1        1/1/2012 1:00         -1.8         -3.7  ...         8.0    101.24      Fog
# 4        1/1/2012 4:00         -1.5         -3.3  ...         4.8    101.23      Fog
# 5        1/1/2012 5:00         -1.4         -3.3  ...         6.4    101.27      Fog
# 6        1/1/2012 6:00         -1.5         -3.1  ...         6.4    101.29      Fog
# ...                ...          ...          ...  ...         ...       ...      ...
# 8716   12/29/2012 4:00        -16.0        -17.2  ...         9.7    101.25      Fog
# 8717   12/29/2012 5:00        -14.8        -15.9  ...         6.4    101.25      Fog
# 8718   12/29/2012 6:00        -13.8        -15.3  ...         9.7    101.25      Fog
# 8719   12/29/2012 7:00        -14.8        -16.4  ...         8.0    101.22      Fog
# ...

# %%
# Groupby
data.groupby('Weather').get_group('Fog')
# Out:
#              Date_Time  Temperature  Dew_Pt_Temp  ...  Visibility  Pressure  Weather
# 0        1/1/2012 0:00         -1.8         -3.9  ...         8.0    101.24      Fog
# 1        1/1/2012 1:00         -1.8         -3.7  ...         8.0    101.24      Fog
# 4        1/1/2012 4:00         -1.5         -3.3  ...         4.8    101.23      Fog
# 5        1/1/2012 5:00         -1.4         -3.3  ...         6.4    101.27      Fog
# 6        1/1/2012 6:00         -1.5         -3.1  ...         6.4    101.29      Fog
# ...                ...          ...          ...  ...         ...       ...      ...
# 8716   12/29/2012 4:00        -16.0        -17.2  ...         9.7    101.25      Fog
# 8717   12/29/2012 5:00        -14.8        -15.9  ...         6.4    101.25      Fog
# 8718   12/29/2012 6:00        -13.8        -15.3  ...         9.7    101.25      Fog
# 8719   12/29/2012 7:00        -14.8        -16.4  ...         8.0    101.22      Fog
# ...

# %%
#Str.contains
data[data.Weather.str.contains('Fog')]
# Out:
#              Date_Time  Temperature  ...  Pressure               Weather
# 0        1/1/2012 0:00         -1.8  ...    101.24                   Fog
# 1        1/1/2012 1:00         -1.8  ...    101.24                   Fog
# 2        1/1/2012 2:00         -1.8  ...    101.26  Freezing Drizzle,Fog
# 3        1/1/2012 3:00         -1.5  ...    101.27  Freezing Drizzle,Fog
# 4        1/1/2012 4:00         -1.5  ...    101.23                   Fog
# ...                ...          ...  ...       ...                   ...
# 8739   12/30/2012 3:00         -9.1  ...    100.30              Snow,Fog
# 8740   12/30/2012 4:00         -9.3  ...    100.28              Snow,Fog
# 8741   12/30/2012 5:00         -9.1  ...    100.32              Snow,Fog
# 8742   12/30/2012 6:00         -9.3  ...    100.39              Snow,Fog
# 8770  12/31/2012 10:00         -7.4  ...    101.05              Snow,Fog
#
# [426 rows x 8 columns]

# %% [markdown]
# Finding instances where weather is clear and visibility is above 40.

# %%
data[(data.Weather=='Clear') & (data.Visibility>40)]
# Out:
#              Date_Time  Temperature  Dew_Pt_Temp  ...  Visibility  Pressure  Weather
# 351    1/15/2012 15:00        -15.4        -22.8  ...        48.3    102.71    Clear
# 352    1/15/2012 16:00        -15.1        -22.8  ...        48.3    102.79    Clear
# 425    1/18/2012 17:00        -11.3        -18.8  ...        48.3    101.54    Clear
# 440     1/19/2012 8:00        -13.7        -18.4  ...        48.3    101.84    Clear
# 441     1/19/2012 9:00        -12.7        -17.2  ...        48.3    101.73    Clear
# ...                ...          ...          ...  ...         ...       ...      ...
# 8384   12/15/2012 8:00        -10.7        -15.6  ...        48.3    102.69    Clear
# 8385   12/15/2012 9:00        -10.4        -15.9  ...        48.3    102.74    Clear
# 8389  12/15/2012 13:00         -8.4        -14.7  ...        48.3    102.64    Clear
# 8631  12/25/2012 15:00         -7.1        -13.7  ...        48.3    101.98    Clear
# ...

# %% [markdown]
# Finding all instances when
# >> (a) Weather is clear and Relative_Humidity is greater than 50.
# >> (b)or Visibility > 50

# %%
data[((data.Weather=='Clear') & (data.Relative_Humidity>50)) | (data.Visibility>40)]
# Out:
#              Date_Time  Temperature  ...  Pressure        Weather
# 106     1/5/2012 10:00         -6.0  ...    100.45   Mainly Clear
# 107     1/5/2012 11:00         -5.6  ...    100.41   Mainly Clear
# 108     1/5/2012 12:00         -4.7  ...    100.38   Mainly Clear
# 109     1/5/2012 13:00         -4.4  ...    100.40   Mainly Clear
# 110     1/5/2012 14:00         -5.1  ...    100.46   Mainly Clear
# ...                ...          ...  ...       ...            ...
# 8749  12/30/2012 13:00        -12.4  ...    100.92  Mostly Cloudy
# 8750  12/30/2012 14:00        -11.8  ...    100.96   Mainly Clear
# 8751  12/30/2012 15:00        -11.3  ...    101.05   Mainly Clear
# 8752  12/30/2012 16:00        -11.4  ...    101.15   Mainly Clear
# 8756  12/30/2012 20:00        -13.8  ...    101.52          Clear
#
# [2921 rows x 8 columns]
